# %% [markdown]
# ### Let's Grow More (LGMVIP) - "DATA SCIENCE INTERN"
#
# ### LGMVIP AUGUST 2022
#
# ### NAME: PRAGATI PRASAD
#
# ### BEGINNER LEVEL TASK
#
# ### TASK-1- Iris Flowers Classification ML Project :
#
# This particular ML project is usually referred to as the “Hello World” of Machine Learning. The iris flowers dataset contains numeric attributes, and it is perfect for beginners to learn about supervised ML algorithms, mainly how to load and handle data. Also, since this is a small dataset, it can easily fit in memory without requiring special transformations or scaling capabilities.
#
# ### Dataset link : http://archive.ics.uci.edu/ml/machine-learning-databases/iris

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn

# %% [markdown]
# ### Importing dataset

# %%
df = pd.read_csv("iris.csv")
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.tail()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.shape
# Out:
# (150, 5)

# %%
df.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
df.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
unique_variety = df['variety'].unique()
unique_variety = unique_variety.tolist()
unique_variety
# Out:
# ['Setosa', 'Versicolor', 'Virginica']

# %%
variety_count = df['variety'].value_counts()
count = variety_count.tolist()
variety_count.to_frame()
# Out:
#             variety
# Setosa           50
# Versicolor       50
# Virginica        50

# %% [markdown]
# ### Data Visualization

# %%
sn.pairplot(df,hue="variety")

# %%
plt.figure(figsize=(16,4))
plt.subplot(1,4,1)
sn.boxplot(data=df,y='sepal.length',color = 'red')
plt.subplot(1,4,2)
sn.boxplot(data=df,y='sepal.width',color='yellow')
plt.subplot(1,4,3)
sn.boxplot(data=df,y='petal.length',color='magenta')
plt.subplot(1,4,4)
sn.boxplot(data=df,y='petal.width',color='cyan')
# Out:
# <AxesSubplot:ylabel='petal.width'>

# %%
sn.violinplot(y='variety', x='sepal.length', data=df, inner='quartile')
plt.show()
sn.violinplot(y='variety', x='sepal.width', data=df, inner='quartile')
plt.show()
sn.violinplot(y='variety', x='petal.length', data=df, inner='quartile')
plt.show()
sn.violinplot(y='variety', x='petal.width', data=df, inner='quartile')
plt.show()

# %%
plt.figure(figsize=(6,5))
sn.heatmap(df.corr(), annot=True,cmap="Greens")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['variety'] = le.fit_transform(df['variety'])
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %% [markdown]
# ### train_test_split

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns=['variety'])
Y = df['variety']
X_train , X_test , Y_train , Y_test = train_test_split(X , Y , test_size = 0.3)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
pred_log=model.predict(X_test)
score=accuracy_score(Y_test,pred_log)
score
# Out:
# 0.9777777777777777

# %%
print(classification_report(Y_pred,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.25      0.32        20
#            1       0.22      0.44      0.30         9
#            2       0.19      0.19      0.19        16
#
#     accuracy                           0.27        45
#    macro avg       0.29      0.29      0.27        45
# weighted avg       0.31      0.27      0.27        45

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtree=model.predict(X_test)
score=accuracy_score(Y_test,pred_dtree)
score
# Out:
# 0.9555555555555556

# %%
print(classification_report(Y_pred,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.25      0.32        20
#            1       0.22      0.44      0.30         9
#            2       0.19      0.19      0.19        16
#
#     accuracy                           0.27        45
#    macro avg       0.29      0.29      0.27        45
# weighted avg       0.31      0.27      0.27        45

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
model.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
pred_knn=model.predict(X_test)
score=accuracy_score(Y_test,pred_knn)
score
# Out:
# 0.9555555555555556

# %%
print(classification_report(Y_pred,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.25      0.32        20
#            1       0.22      0.44      0.30         9
#            2       0.19      0.19      0.19        16
#
#     accuracy                           0.27        45
#    macro avg       0.29      0.29      0.27        45
# weighted avg       0.31      0.27      0.27        45

# %%
summary = pd.DataFrame({'Models': ["Logistic Reg","Decision Tree","KNN"],
                           'Accuracies': [accuracy_score(Y_test,pred_log),accuracy_score(Y_test,pred_dtree),accuracy_score(Y_test,pred_knn)]
                           })
summary
# Out:
#           Models  Accuracies
# 0   Logistic Reg    0.977778
# 1  Decision Tree    0.955556
# 2            KNN    0.955556
